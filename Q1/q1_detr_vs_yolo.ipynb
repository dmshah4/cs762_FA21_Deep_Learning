# %%
# !pip install grad-cam
# !pip install ttach
# !pip install timm
# Out:
# Requirement already satisfied: ttach in /usr/local/lib/python3.7/dist-packages (0.0.3)
# Requirement already satisfied: timm in /usr/local/lib/python3.7/dist-packages (0.4.12)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.11.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (3.10.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.19.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)

# %%
# !git clone https://github.com/vigneshuw/pytorch-grad-cam.git
# !pip install pytorch-grad-cam/
# Out:
# fatal: destination path 'pytorch-grad-cam' already exists and is not an empty directory.
# Processing ./pytorch-grad-cam
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.7/dist-packages (from grad-cam==1.3.2) (0.11.1+cu111)
# Requirement already satisfied: tqdm>=4.42 in /usr/local/lib/python3.7/dist-packages (from grad-cam==1.3.2) (4.62.3)
# Requirement already satisfied: ttach>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from grad-cam==1.3.2) (0.0.3)
# Requirement already satisfied: opencv-python>=4.5torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from grad-cam==1.3.2) (4.5.4.60)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.5torch>=1.4->grad-cam==1.3.2) (1.19.5)
# Requirement already satisfied: torch==1.10.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5->grad-cam==1.3.2) (1.10.0+cu111)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5->grad-cam==1.3.2) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.0->torchvision>=0.5->grad-cam==1.3.2) (3.10.0.2)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (PEP 517) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.3.2-py3-none-any.whl size=20658 sha256=c832f2c0c0fd6cf0ea0369f329d61149624a1b16a4cb64a2813d36dffce784e6
#   Stored in directory: /root/.cache/pip/wheels/cd/cb/7e/31a3553b353ebe761ab45b4267c016ff23c49ba5acd801a813
# Successfully built grad-cam
# Installing collected packages: grad-cam
#   Attempting uninstall: grad-cam
#     Found existing installation: grad-cam 1.3.2
#     Uninstalling grad-cam-1.3.2:
#       Successfully uninstalled grad-cam-1.3.2
# Successfully installed grad-cam-1.3.2

# %%
# Google Collab Requirements / Checks
from google.colab.patches import cv2_imshow # Change this before running elsewhere!!

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# cd into yolo directory
# %cd "/content/gdrive/MyDrive/CS762_Deep_Learning_Project/yolov3"
# Out:
# /content/gdrive/MyDrive/CS762_Deep_Learning_Project/yolov3

# %%
# Imports
import os
import cv2
import glob
import gc
import numpy as np
import pandas as pd
import copy
import math

from PIL import Image

import torch
from torch.autograd import Variable
from torchvision import transforms

import darknet as dn
from darknet_util import write_results

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image

# %%
# Load manual ms coco dataset and bounding boxes
# Varun's Directory
# dir_uri = '/content/gdrive/MyDrive/University of Wisconsin-Madison/2021 Fall/cs762'
# Devesh's Directory
dir_uri = '/content/gdrive/MyDrive'

proj_dir = dir_uri + '/CS762_Deep_Learning_Project'
df = pd.read_excel( proj_dir + '/fullBBOX.xlsx')

dataset_folder = dir_uri + '/CS762_Deep_Learning_Project/datasets/Manual_MSCOCO' 
image_names = []
for filename in os.listdir(dataset_folder):
  image_names.append(filename)

image_names.sort(key=lambda x: int(x.split('-')[0]))

# Yolo COCO classes (80 only)
def load_classes(namesfile):
    fp = open(namesfile, "r")
    names = fp.read().split("\n")[:-1]
    return names

yolo_classes = load_classes("data/coco.names")

# DETR COCO classes (91 - acutally 80 when N/A removed)
DETR_CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# Load iamge net categories
imageNet_labels_path = dir_uri + "/CS762_Deep_Learning_Project/datasets/imagenet_classes.txt"
# Read the categories
with open(imageNet_labels_path, "r") as f:
    categories = [s.strip() for s in f.readlines()]

# Load bbox's
bbox_path = proj_dir + '/fullBBOX.xlsx'
bbox_df = pd.read_excel(bbox_path)
all_boxes = bbox_df.to_numpy()

output_file = proj_dir + '/Q1/q1_output_detr_yolo.csv'
headers = ['image_name', 'threshold', 'yolo label', 'yolo accuracy', 'yolo whole image %', 'yolo in bbox %', 'yolo outside bbox %', 'detr label', 'detr accuracy', 'detr whole image %', 'detr in bbox %', 'detr outside bbox %']

# %%
yolo_transform = transforms.Compose([
    transforms.Resize((416, 416)),
    transforms.ToTensor(),
])

detr_transform = transforms.Compose([
    transforms.Resize(800),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


# bbox given as one row from our fullBBox.xlsx file
def eval_metric_percent_above(grayscale_cam, bbox, threshold):

    # find area of bbox
    topLeft_w = int(bbox[2])
    topLeft_h = int(bbox[3])
    botRight_w = int(bbox[6])
    botRight_h = int(bbox[7])
    width_bbox = abs(botRight_w - topLeft_w)
    height_bbox = abs(topLeft_h - botRight_h)
    area = width_bbox * height_bbox

    # percent above threshold whole image
    above_threshold = (grayscale_cam > threshold)
    count_above_threshold = above_threshold.sum()
    total_count = grayscale_cam.shape[0] * grayscale_cam.shape[1]
    percent_above_threshold_whole_image = (count_above_threshold / total_count) * 100

    # percent above threshold in bbox
    bbox_grayscale_cam = grayscale_cam[topLeft_h:botRight_h, topLeft_w:botRight_w]
    bbox_above_threshold = (bbox_grayscale_cam > threshold)
    bbox_count_above_threshold = bbox_above_threshold.sum()
    bbox_total_count = bbox_grayscale_cam.shape[0] * bbox_grayscale_cam.shape[1]
    percent_above_threshold_in_bbox = (bbox_count_above_threshold / bbox_total_count) * 100

    # percent above threshold outside bbox
    outside_bbox_cam = copy.deepcopy(grayscale_cam)
    outside_bbox_cam[topLeft_h:botRight_h, topLeft_w:botRight_w] = np.zeros((height_bbox, width_bbox))
    outside_bbox_above_threshold = (outside_bbox_cam > threshold)
    outside_bbox_count_above_threshold = outside_bbox_above_threshold.sum()
    outside_bbox_total_count = total_count - bbox_total_count
    percent_above_threshold_outside_bbox = (outside_bbox_count_above_threshold / outside_bbox_total_count) * 100

    # return
    return percent_above_threshold_whole_image, percent_above_threshold_in_bbox, percent_above_threshold_outside_bbox


def resizeBbox(orig_bbox, orig_img_size, new_img_size):
    orig_h = orig_img_size[0]
    orig_w = orig_img_size[1]
    new_h = new_img_size[0]
    new_w = new_img_size[1]

    h_ratio = new_h / orig_h
    w_ratio = new_w / orig_w

    new_bbox = copy.deepcopy(orig_bbox)
    new_bbox[2] = orig_bbox[2] * w_ratio
    new_bbox[3] = orig_bbox[3] * h_ratio
    new_bbox[4] = orig_bbox[4] * w_ratio
    new_bbox[5] = orig_bbox[5] * h_ratio
    new_bbox[6] = orig_bbox[6] * w_ratio
    new_bbox[7] = orig_bbox[7] * h_ratio
    new_bbox[8] = orig_bbox[8] * w_ratio
    new_bbox[9] = orig_bbox[9] * h_ratio

    return new_bbox

# %%
yolo_transform_eval = transforms.Compose([
    transforms.Resize((416, 416)),
])

detr_transform_eval = transforms.Compose([
    transforms.Resize(800),
])


def show_cam_on_image_updated(img: np.ndarray,
                      mask: np.ndarray,
                      use_rgb: bool = False,
                      colormap: int = cv2.COLORMAP_JET) -> np.ndarray:
    """ This function overlays the cam mask on the image as an heatmap.
    By default the heatmap is in BGR format.
    :param img: The base image in RGB or BGR format.
    :param mask: The cam mask.
    :param use_rgb: Whether to use an RGB or BGR heatmap, this should be set to True if 'img' is in RGB format.
    :param colormap: The OpenCV colormap to be used.
    :returns: The default image with the cam overlay.
    """
    heatmap = cv2.applyColorMap(np.uint8(255 * mask), colormap)
    if use_rgb:
        heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
    heatmap = np.float32(heatmap) / 255

    if np.max(img) > 1:
        raise Exception(
            "The input image should np.float32 in the range [0, 1]")

    cam = heatmap + img
    cam = cam / np.max(cam)
    return heatmap, np.uint8(255 * cam)


def visualize_eval_metric(rgb_image, grayscale_cam, heatmap, bbox, threshold):
    red_color = (0, 0, 255)
    thickness = 2
    start_point = (int(bbox[2]), int(bbox[3]))
    end_point = (int(bbox[6]), int(bbox[7]))

    above_threshold = (grayscale_cam > threshold)

    for i in range(grayscale_cam.shape[0]):
      for j in range(grayscale_cam.shape[1]):
        if(above_threshold[i, j] == False):
          heatmap[i,j,0] = 0
          heatmap[i,j,1] = 0
          heatmap[i,j,2] = 0

    cam = heatmap + rgb_image
    cam = cam / np.max(cam)
    cam = np.uint8(255 * cam)
    cam = cv2.rectangle(cam, start_point, end_point, red_color, thickness)
    return cam

# for output bounding box post-processing
def detr_box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def detr_rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = detr_box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# PLotting the results
def get_detr_label_and_prob(pil_img, prob, boxes, target_class):
    label = None
    max_prob = 0

    colors = COLORS * 100
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
        cl = p.argmax()
        if (DETR_CLASSES[cl] == target_class):
          if p[cl] > max_prob:
            label = DETR_CLASSES[cl]
            max_prob = p[cl]
    
    return label, max_prob

# %%
def show_cam_on_image_updated_blank(img: np.ndarray,
                      mask: np.ndarray,
                      use_rgb: bool = False,
                      colormap: int = cv2.COLORMAP_JET) -> np.ndarray:
    """ This function overlays the cam mask on the image as an heatmap.
    By default the heatmap is in BGR format.
    :param img: The base image in RGB or BGR format.
    :param mask: The cam mask.
    :param use_rgb: Whether to use an RGB or BGR heatmap, this should be set to True if 'img' is in RGB format.
    :param colormap: The OpenCV colormap to be used.
    :returns: The default image with the cam overlay.
    """
    heatmap = cv2.applyColorMap(np.uint8(255 * mask), colormap)
    if use_rgb:
        heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
    heatmap = np.float32(heatmap) / 255

    if np.max(img) > 1:
        raise Exception(
            "The input image should np.float32 in the range [0, 1]")

    #print(img.shape)
    img[(img[:,:,0]<300) & (img[:,:,1]<300) & (img[:,:,2]<300)] = [1,1,1] 
    cam = heatmap + img
    cam = cam / np.max(cam)
    return heatmap, np.uint8(255 * cam)

# %%
torch.set_grad_enabled(True)

blocks = dn.parse_cfg("cfg/yolov3.cfg")
yolo_model = dn.create_modules(blocks)

yolo_model = dn.Darknet("cfg/yolov3.cfg", False)

yolo_model.load_weights("weights/yolov3.weights")
yolo_model.eval();

#### Adding the gradient function to the tensors
for param in yolo_model.parameters():
    param.requires_grad = True

detr_model = torch.hub.load('facebookresearch/detr', 'detr_resnet50', pretrained=True)
detr_model.eval();

 #### Adding the gradient function to the tensors
for param in detr_model.parameters():
    param.requires_grad = True
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_detr_main

# %%
yolo_target_layers = [yolo_model.module_list[77].conv_77]
detr_target_layers = [detr_model.input_proj]

target_category = None

yolo_input_image_shape = (416, 416, 3)
#detr_input_image_shape = (800, ___, 3)

threshold_options = [0.7, 0.9]

# %%
output_data = []

for threshold in threshold_options:
  for i in range(len( image_names ) ):
    print(image_names[i])

    # Create input
    test_img = Image.open( dataset_folder + '/' + image_names[i] ).convert('RGB')
    orig_bbox = all_boxes[i]
    orig_img_shape = np.array(test_img).shape

    # Create target lable
    target_name = image_names[i].split( '-' )[1]
    target_name = target_name.split( '.' )[0]

    #
    # YOLO
    #
    
    # YOLO Target label
    # handle mismatch spelling in yolo classes
    yolo_target_name = target_name
    if yolo_target_name == 'airplane':
      yolo_target_name = 'aeroplane'
      
    target_category = [index for index, class_instance in enumerate(yolo_classes) if class_instance == yolo_target_name]

    # Input
    input_tensor = yolo_transform(test_img)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    # Get output
    with torch.no_grad():
      output = yolo_model(input_batch)

    yolo_predicted_label = ''
    yolo_predicted_label_prob = 0

    output = write_results(output[0], 0.5, 80)
    # Find box with target class
    if type(output) != int:
      for box in output:
        if target_category[0] == int(box[7]):
          yolo_predicted_label_prob = 1 / (1 + math.exp(-float(box[6])))
          yolo_predicted_label = target_name
          break

    if ( yolo_predicted_label == '' ):
      print( "YOLO did not get true classification for: {}".format( image_names[i] ) )

    # Grad cam time
    yolo_cam = GradCAM(model=yolo_model, target_layers=yolo_target_layers, use_cuda=False, reshape_transform=None, classification_logit="pred_logits")
    yolo_grayscale_cam = yolo_cam(input_tensor=input_batch, target_category=target_category, eigen_smooth=False, aug_smooth=False)
    yolo_grayscale_cam = yolo_grayscale_cam[0, :]

    # resize bbox and calculate metrics
    new_bbox_yolo = resizeBbox(orig_bbox, (orig_img_shape[0], orig_img_shape[1]), (yolo_input_image_shape[0], yolo_input_image_shape[1]))
    yolo_whole_img, yolo_in_bbox, yolo_out_bbox = eval_metric_percent_above(yolo_grayscale_cam, new_bbox_yolo, threshold)


    #
    # DETR
    #

    # DETR Target Label
    target_category = [index for index, class_instance in enumerate(DETR_CLASSES) if class_instance == target_name]

    # Input
    input_tensor = detr_transform(test_img)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    # Compute the predictions
    with torch.no_grad():
      output = detr_model(input_batch)

    # and convert them into probabilities
    # keep only predictions with 0.7+ confidence
    probas = output['pred_logits'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > 0.9

    # finally get the index of the prediction with highest score
    detr_predicted_label = None
    detr_predicted_label_prob = 0

    # convert boxes from [0; 1] to image scales
    bboxes_scaled = detr_rescale_bboxes(output['pred_boxes'][0, keep], test_img.size)

    detr_predicted_label, detr_predicted_label_prob = get_detr_label_and_prob(test_img, probas[keep], bboxes_scaled, target_name)

    # Grad cam time
    detr_cam = GradCAM(model=detr_model, target_layers=detr_target_layers, use_cuda=False, reshape_transform=None, classification_logit="pred_logits")
    detr_grayscale_cam = detr_cam(input_tensor=input_batch, target_category=target_category, eigen_smooth=False, aug_smooth=False)
    detr_grayscale_cam = detr_grayscale_cam[0, :]

    # resize bbox and calculate metrics
    detr_input_image_shape = (detr_grayscale_cam.shape[0], detr_grayscale_cam.shape[1], 3)
    new_bbox_detr = resizeBbox(orig_bbox, (orig_img_shape[0], orig_img_shape[1]), (detr_input_image_shape[0], detr_input_image_shape[1]))
    detr_whole_img, detr_in_bbox, detr_out_bbox = eval_metric_percent_above(detr_grayscale_cam, new_bbox_detr, threshold)

    output_data.append( [image_names[i], threshold, yolo_predicted_label, yolo_predicted_label_prob, yolo_whole_img, yolo_in_bbox, yolo_out_bbox, detr_predicted_label, detr_predicted_label_prob, detr_whole_img, detr_in_bbox, detr_out_bbox] )

    # Delete garbage for ram
    gc.collect()
# Out:
# 0-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(5.5308, grad_fn=<AddBackward0>)]
# /root/.cache/torch/hub/facebookresearch_detr_main/models/position_encoding.py:41: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
# <class 'dict'>
# The max logit value is [tensor(13.5611, grad_fn=<AddBackward0>)]
# 1-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(3.9925, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1433, grad_fn=<AddBackward0>)]
# 2-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(4.5802, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5805, grad_fn=<AddBackward0>)]
# 3-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-10.4102, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3409, grad_fn=<AddBackward0>)]
# 4-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.7897, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6876, grad_fn=<AddBackward0>)]
# 5-person.png
# <class 'tuple'>
# The max logit value is [tensor(10.7237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1653, grad_fn=<AddBackward0>)]
# 6-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.8391, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5269, grad_fn=<AddBackward0>)]
# 7-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.6263, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8881, grad_fn=<AddBackward0>)]
# 8-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.5815, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5420, grad_fn=<AddBackward0>)]
# 9-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.6381, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3702, grad_fn=<AddBackward0>)]
# 10-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.4378, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0519, grad_fn=<AddBackward0>)]
# 11-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5853, grad_fn=<AddBackward0>)]
# 12-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(4.3439, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1189, grad_fn=<AddBackward0>)]
# 13-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-11.2419, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7280, grad_fn=<AddBackward0>)]
# 14-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.5862, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2912, grad_fn=<AddBackward0>), tensor(12.8169, grad_fn=<AddBackward0>)]
# 15-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.2505, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7286, grad_fn=<AddBackward0>)]
# 16-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.4982, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7591, grad_fn=<AddBackward0>)]
# 17-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.8589, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2224, grad_fn=<AddBackward0>)]
# 18-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.2969, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0014, grad_fn=<AddBackward0>)]
# 19-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.8186, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.9192, grad_fn=<AddBackward0>), tensor(12.4240, grad_fn=<AddBackward0>)]
# 20-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.2846, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1706, grad_fn=<AddBackward0>)]
# 21-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.8542, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.3482, grad_fn=<AddBackward0>)]
# 22-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(10.0436, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5283, grad_fn=<AddBackward0>)]
# 23-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.4073, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.4699, grad_fn=<AddBackward0>)]
# 24-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-13.0639, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8216, grad_fn=<AddBackward0>), tensor(13.7852, grad_fn=<AddBackward0>)]
# 25-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(10.9264, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2152, grad_fn=<AddBackward0>)]
# 26-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.7400, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8655, grad_fn=<AddBackward0>)]
# 27-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.5422, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7718, grad_fn=<AddBackward0>)]
# 28-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.4477, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2496, grad_fn=<AddBackward0>), tensor(10.3612, grad_fn=<AddBackward0>)]
# 29-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-15.4661, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1834, grad_fn=<AddBackward0>)]
# 30-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(4.5230, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2386, grad_fn=<AddBackward0>)]
# 31-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.9237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8533, grad_fn=<AddBackward0>)]
# 32-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.4350, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.4381, grad_fn=<AddBackward0>)]
# 33-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.4023, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.5508, grad_fn=<AddBackward0>), tensor(10.1962, grad_fn=<AddBackward0>)]
# 34-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.9054, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.0500, grad_fn=<AddBackward0>)]
# 35-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.4827, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2102, grad_fn=<AddBackward0>)]
# 36-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.1681, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3062, grad_fn=<AddBackward0>)]
# 37-cat.jpeg
# YOLO did not get true classification for: 37-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-3.6744, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0674, grad_fn=<AddBackward0>)]
# 38-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.1773, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7987, grad_fn=<AddBackward0>)]
# 39-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-7.5615, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8895, grad_fn=<AddBackward0>)]
# 40-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(5.9256, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1859, grad_fn=<AddBackward0>)]
# 41-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9152, grad_fn=<AddBackward0>)]
# 42-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.0157, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1642, grad_fn=<AddBackward0>)]
# 43-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-4.8990, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3817, grad_fn=<AddBackward0>)]
# 44-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-9.0738, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9484, grad_fn=<AddBackward0>)]
# 45-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.7179, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6399, grad_fn=<AddBackward0>)]
# 46-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(2.3924, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2561, grad_fn=<AddBackward0>)]
# 47-elephant.png
# <class 'tuple'>
# The max logit value is [tensor(3.9677, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.7378, grad_fn=<AddBackward0>)]
# 48-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.7508, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1482, grad_fn=<AddBackward0>)]
# 49-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(1.8393, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4236, grad_fn=<AddBackward0>)]
# 50-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.0784, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2230, grad_fn=<AddBackward0>)]
# 51-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(8.4209, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6074, grad_fn=<AddBackward0>)]
# 52-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.4780, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9774, grad_fn=<AddBackward0>)]
# 53-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(-8.8036, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1900, grad_fn=<AddBackward0>)]
# 54-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(-7.8244, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2619, grad_fn=<AddBackward0>)]
# 55-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(-0.5951, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.0699, grad_fn=<AddBackward0>)]
# 56-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(4.4417, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.3201, grad_fn=<AddBackward0>)]
# 57-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(3.7145, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3823, grad_fn=<AddBackward0>)]
# 58-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(-5.5045, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5649, grad_fn=<AddBackward0>), tensor(10.6699, grad_fn=<AddBackward0>)]
# 59-backpack.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-7.5828, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7559, grad_fn=<AddBackward0>)]
# 60-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(4.7581, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.7177, grad_fn=<AddBackward0>)]
# 61-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(10.3396, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8450, grad_fn=<AddBackward0>)]
# 62-umbrella.jpg
# YOLO did not get true classification for: 62-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(-4.2198, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6159, grad_fn=<AddBackward0>)]
# 63-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(10.9254, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5183, grad_fn=<AddBackward0>)]
# 64-umbrella.jpg
# YOLO did not get true classification for: 64-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(-10.2075, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4458, grad_fn=<AddBackward0>), tensor(10.8906, grad_fn=<AddBackward0>), tensor(10.5400, grad_fn=<AddBackward0>), tensor(9.5037, grad_fn=<AddBackward0>), tensor(10.5132, grad_fn=<AddBackward0>)]
# 65-parking meter.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.3321, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3324, grad_fn=<AddBackward0>)]
# 66-parking meter.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.3800, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9643, grad_fn=<AddBackward0>)]
# 67-parking meter.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.5889, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1103, grad_fn=<AddBackward0>)]
# 68-parking meter.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.5506, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6464, grad_fn=<AddBackward0>), tensor(10.3465, grad_fn=<AddBackward0>), tensor(10.9078, grad_fn=<AddBackward0>)]
# 69-parking meter.jpg
# <class 'tuple'>
# The max logit value is [tensor(-13.3801, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.1126, grad_fn=<AddBackward0>)]
# 70-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.9034, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9821, grad_fn=<AddBackward0>)]
# 71-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.3267, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6656, grad_fn=<AddBackward0>)]
# 72-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.8161, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9558, grad_fn=<AddBackward0>)]
# 73-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.7174, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6899, grad_fn=<AddBackward0>)]
# 74-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.4084, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3030, grad_fn=<AddBackward0>)]
# 75-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.5086, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0514, grad_fn=<AddBackward0>)]
# 76-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.8309, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8245, grad_fn=<AddBackward0>)]
# 77-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(5.7582, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8324, grad_fn=<AddBackward0>)]
# 78-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.5599, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.1073, grad_fn=<AddBackward0>)]
# 79-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.7845, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3465, grad_fn=<AddBackward0>), tensor(12.2098, grad_fn=<AddBackward0>)]
# 80-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.1103, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2999, grad_fn=<AddBackward0>)]
# 81-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-10.1368, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6304, grad_fn=<AddBackward0>)]
# 82-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-9.6012, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3417, grad_fn=<AddBackward0>)]
# 83-scissors.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-9.6016, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5807, grad_fn=<AddBackward0>)]
# 84-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-4.7332, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.4389, grad_fn=<AddBackward0>)]
# 85-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.3527, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8786, grad_fn=<AddBackward0>)]
# 86-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(-14.7406, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6798, grad_fn=<AddBackward0>)]
# 87-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.0412, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5863, grad_fn=<AddBackward0>)]
# 88-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.8322, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.9161, grad_fn=<AddBackward0>)]
# 89-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.0760, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2207, grad_fn=<AddBackward0>)]
# 90-vase.jpg
# YOLO did not get true classification for: 90-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(-12.8192, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1463, grad_fn=<AddBackward0>)]
# 91-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(-13.7556, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2732, grad_fn=<AddBackward0>)]
# 92-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.6488, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8657, grad_fn=<AddBackward0>)]
# 93-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(-12.8614, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6885, grad_fn=<AddBackward0>)]
# 94-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.5220, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9689, grad_fn=<AddBackward0>)]
# 95-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.5919, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6179, grad_fn=<AddBackward0>)]
# 96-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(3.6957, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5961, grad_fn=<AddBackward0>)]
# 97-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(3.7360, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9742, grad_fn=<AddBackward0>)]
# 98-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(1.4690, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5712, grad_fn=<AddBackward0>)]
# 99-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(-8.8549, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(8.7585, grad_fn=<AddBackward0>)]
# 0-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(5.5308, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5611, grad_fn=<AddBackward0>)]
# 1-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(3.9925, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1433, grad_fn=<AddBackward0>)]
# 2-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(4.5802, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5805, grad_fn=<AddBackward0>)]
# 3-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-10.4102, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3409, grad_fn=<AddBackward0>)]
# 4-bicycle.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.7897, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6876, grad_fn=<AddBackward0>)]
# 5-person.png
# <class 'tuple'>
# The max logit value is [tensor(10.7237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1653, grad_fn=<AddBackward0>)]
# 6-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.8391, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5269, grad_fn=<AddBackward0>)]
# 7-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.6263, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8881, grad_fn=<AddBackward0>)]
# 8-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.5815, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5420, grad_fn=<AddBackward0>)]
# 9-person.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.6381, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3702, grad_fn=<AddBackward0>)]
# 10-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.4378, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0519, grad_fn=<AddBackward0>)]
# 11-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5853, grad_fn=<AddBackward0>)]
# 12-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(4.3439, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1189, grad_fn=<AddBackward0>)]
# 13-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-11.2419, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7280, grad_fn=<AddBackward0>)]
# 14-car.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.5862, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2912, grad_fn=<AddBackward0>), tensor(12.8169, grad_fn=<AddBackward0>)]
# 15-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.2505, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7286, grad_fn=<AddBackward0>)]
# 16-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.4982, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7591, grad_fn=<AddBackward0>)]
# 17-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.8589, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2224, grad_fn=<AddBackward0>)]
# 18-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.2969, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0014, grad_fn=<AddBackward0>)]
# 19-airplane.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.8186, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.9192, grad_fn=<AddBackward0>), tensor(12.4240, grad_fn=<AddBackward0>)]
# 20-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(9.2846, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1706, grad_fn=<AddBackward0>)]
# 21-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.8542, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.3482, grad_fn=<AddBackward0>)]
# 22-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(10.0436, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5283, grad_fn=<AddBackward0>)]
# 23-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.4073, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.4699, grad_fn=<AddBackward0>)]
# 24-bus.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-13.0639, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8216, grad_fn=<AddBackward0>), tensor(13.7852, grad_fn=<AddBackward0>)]
# 25-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(10.9264, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2152, grad_fn=<AddBackward0>)]
# 26-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.7400, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8655, grad_fn=<AddBackward0>)]
# 27-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.5422, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7718, grad_fn=<AddBackward0>)]
# 28-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.4477, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2496, grad_fn=<AddBackward0>), tensor(10.3612, grad_fn=<AddBackward0>)]
# 29-fire hydrant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-15.4661, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1834, grad_fn=<AddBackward0>)]
# 30-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(4.5230, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2386, grad_fn=<AddBackward0>)]
# 31-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.9237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8533, grad_fn=<AddBackward0>)]
# 32-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.4350, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.4381, grad_fn=<AddBackward0>)]
# 33-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.4023, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.5508, grad_fn=<AddBackward0>), tensor(10.1962, grad_fn=<AddBackward0>)]
# 34-bird.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-12.9054, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.0500, grad_fn=<AddBackward0>)]
# 35-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.4827, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2102, grad_fn=<AddBackward0>)]
# 36-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.1681, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3062, grad_fn=<AddBackward0>)]
# 37-cat.jpeg
# YOLO did not get true classification for: 37-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-3.6744, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0674, grad_fn=<AddBackward0>)]
# 38-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.1773, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7987, grad_fn=<AddBackward0>)]
# 39-cat.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-7.5615, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8895, grad_fn=<AddBackward0>)]
# 40-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(5.9256, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1859, grad_fn=<AddBackward0>)]
# 41-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9152, grad_fn=<AddBackward0>)]
# 42-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(8.0157, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1642, grad_fn=<AddBackward0>)]
# 43-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-4.8990, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3817, grad_fn=<AddBackward0>)]
# 44-dog.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-9.0738, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9484, grad_fn=<AddBackward0>)]
# 45-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.7179, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6399, grad_fn=<AddBackward0>)]
# 46-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(2.3924, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2561, grad_fn=<AddBackward0>)]
# 47-elephant.png
# <class 'tuple'>
# The max logit value is [tensor(3.9677, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.7378, grad_fn=<AddBackward0>)]
# 48-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.7508, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1482, grad_fn=<AddBackward0>)]
# 49-elephant.jpeg
# <class 'tuple'>
# The max logit value is [tensor(1.8393, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4236, grad_fn=<AddBackward0>)]
# 50-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.0784, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2230, grad_fn=<AddBackward0>)]
# 51-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(8.4209, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6074, grad_fn=<AddBackward0>)]
# 52-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.4780, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9774, grad_fn=<AddBackward0>)]
# 53-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(-8.8036, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1900, grad_fn=<AddBackward0>)]
# 54-zebra.jpg
# <class 'tuple'>
# The max logit value is [tensor(-7.8244, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2619, grad_fn=<AddBackward0>)]
# 55-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(-0.5951, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.0699, grad_fn=<AddBackward0>)]
# 56-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(4.4417, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.3201, grad_fn=<AddBackward0>)]
# 57-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(3.7145, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3823, grad_fn=<AddBackward0>)]
# 58-backpack.jpg
# <class 'tuple'>
# The max logit value is [tensor(-5.5045, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5649, grad_fn=<AddBackward0>), tensor(10.6699, grad_fn=<AddBackward0>)]
# 59-backpack.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-7.5828, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7559, grad_fn=<AddBackward0>)]
# 60-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(4.7581, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.7177, grad_fn=<AddBackward0>)]
# 61-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(10.3396, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8450, grad_fn=<AddBackward0>)]
# 62-umbrella.jpg
# YOLO did not get true classification for: 62-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(-4.2198, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6159, grad_fn=<AddBackward0>)]
# 63-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(10.9254, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5183, grad_fn=<AddBackward0>)]
# 64-umbrella.jpg
# YOLO did not get true classification for: 64-umbrella.jpg
# <class 'tuple'>
# The max logit value is [tensor(-10.2075, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4458, grad_fn=<AddBackward0>), tensor(10.8906, grad_fn=<AddBackward0>), tensor(10.5400, grad_fn=<AddBackward0>), tensor(9.5037, grad_fn=<AddBackward0>), tensor(10.5132, grad_fn=<AddBackward0>)]
# 65-parking meter.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.3321, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3324, grad_fn=<AddBackward0>)]
# 66-parking meter.jpeg
# <class 'tuple'>
# The max logit value is [tensor(6.3800, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9643, grad_fn=<AddBackward0>)]
# 67-parking meter.jpeg
# <class 'tuple'>
# The max logit value is [tensor(7.5889, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1103, grad_fn=<AddBackward0>)]
# 68-parking meter.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-14.5506, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6464, grad_fn=<AddBackward0>), tensor(10.3465, grad_fn=<AddBackward0>), tensor(10.9078, grad_fn=<AddBackward0>)]
# 69-parking meter.jpg
# <class 'tuple'>
# The max logit value is [tensor(-13.3801, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.1126, grad_fn=<AddBackward0>)]
# 70-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.9034, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9821, grad_fn=<AddBackward0>)]
# 71-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.3267, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6656, grad_fn=<AddBackward0>)]
# 72-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.8161, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9558, grad_fn=<AddBackward0>)]
# 73-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.7174, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6899, grad_fn=<AddBackward0>)]
# 74-stop sign.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.4084, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3030, grad_fn=<AddBackward0>)]
# 75-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.5086, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0514, grad_fn=<AddBackward0>)]
# 76-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.8309, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8245, grad_fn=<AddBackward0>)]
# 77-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(5.7582, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8324, grad_fn=<AddBackward0>)]
# 78-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.5599, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.1073, grad_fn=<AddBackward0>)]
# 79-wine glass.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.7845, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3465, grad_fn=<AddBackward0>), tensor(12.2098, grad_fn=<AddBackward0>)]
# 80-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.1103, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2999, grad_fn=<AddBackward0>)]
# 81-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-10.1368, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6304, grad_fn=<AddBackward0>)]
# 82-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-9.6012, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3417, grad_fn=<AddBackward0>)]
# 83-scissors.jpeg
# <class 'tuple'>
# The max logit value is [tensor(-9.6016, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5807, grad_fn=<AddBackward0>)]
# 84-scissors.jpg
# <class 'tuple'>
# The max logit value is [tensor(-4.7332, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.4389, grad_fn=<AddBackward0>)]
# 85-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(9.3527, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8786, grad_fn=<AddBackward0>)]
# 86-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(-14.7406, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6798, grad_fn=<AddBackward0>)]
# 87-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.0412, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5863, grad_fn=<AddBackward0>)]
# 88-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.8322, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.9161, grad_fn=<AddBackward0>)]
# 89-mouse.jpg
# <class 'tuple'>
# The max logit value is [tensor(-11.0760, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2207, grad_fn=<AddBackward0>)]
# 90-vase.jpg
# YOLO did not get true classification for: 90-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(-12.8192, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1463, grad_fn=<AddBackward0>)]
# 91-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(-13.7556, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2732, grad_fn=<AddBackward0>)]
# 92-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(7.6488, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8657, grad_fn=<AddBackward0>)]
# 93-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(-12.8614, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6885, grad_fn=<AddBackward0>)]
# 94-vase.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.5220, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9689, grad_fn=<AddBackward0>)]
# 95-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(6.5919, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6179, grad_fn=<AddBackward0>)]
# 96-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(3.6957, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5961, grad_fn=<AddBackward0>)]
# 97-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(3.7360, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9742, grad_fn=<AddBackward0>)]
# 98-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(1.4690, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5712, grad_fn=<AddBackward0>)]
# 99-cup.jpg
# <class 'tuple'>
# The max logit value is [tensor(-8.8549, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(8.7585, grad_fn=<AddBackward0>)]

# %%
df = pd.DataFrame (output_data, columns=headers)
df.to_csv(output_file)

# %%
output_images_dir = proj_dir + '/Q1/output_images/'
images_to_visualize = [50, 56, 60, 63, 67]
threshold = 0.7
generate_vis_analysis = True

# %%
if(generate_vis_analysis):
  #for i in range(0, len(image_names)):
  for i in range(0, 5):
    # Create input
    test_img = Image.open( dataset_folder + '/' + image_names[i] ).convert('RGB')
    yolo_path = output_images_dir + image_names[i] + '_yolo_whole'
    yolo_path_t = output_images_dir + image_names[i] + '_yolo_thres'
    detr_path = output_images_dir + image_names[i] + '_detr_whole'
    detr_path_t = output_images_dir + image_names[i] + '_detr_thres'

    orig_bbox = all_boxes[i]
    orig_img_shape = np.array(test_img).shape

    # Create target lable
    target_name = image_names[i].split( '-' )[1]
    target_name = target_name.split( '.' )[0]

    #
    # YOLO
    #
    
    # YOLO Target label
    # handle mismatch spelling in yolo classes
    yolo_target_name = target_name
    if yolo_target_name == 'airplane':
      yolo_target_name = 'aeroplane'
      
    target_category = [index for index, class_instance in enumerate(yolo_classes) if class_instance == yolo_target_name]

    # Input
    input_tensor = yolo_transform(test_img)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    # Grad cam time
    yolo_cam = GradCAM(model=yolo_model, target_layers=yolo_target_layers, use_cuda=False, reshape_transform=None, classification_logit="pred_logits")
    yolo_grayscale_cam = yolo_cam(input_tensor=input_batch, target_category=target_category, eigen_smooth=False, aug_smooth=False)
    yolo_grayscale_cam = yolo_grayscale_cam[0, :]

    # process image to write gradcam on
    rgb_image = np.array(yolo_transform_eval(test_img)).astype(np.float32)
    rgb_image = rgb_image/255

    # whole image gradcam visualization
    yolo_heatmap, yolo_visualization = show_cam_on_image_updated(rgb_image, yolo_grayscale_cam, use_rgb=False)
    cv2.imwrite(yolo_path, yolo_visualization)

    # resize bbox and calculate metrics
    new_bbox_yolo = resizeBbox(orig_bbox, (orig_img_shape[0], orig_img_shape[1]), (yolo_input_image_shape[0], yolo_input_image_shape[1]))
    yolo_visualized_cam_threshold = visualize_eval_metric(rgb_image, yolo_grayscale_cam, yolo_heatmap, new_bbox_yolo, threshold)
    cv2.imwrite(yolo_path_t, yolo_visualized_cam_threshold)


    ######


    #
    # DETR
    #

    # DETR Target Label
    target_category = [index for index, class_instance in enumerate(DETR_CLASSES) if class_instance == target_name]

    # Input
    input_tensor = detr_transform(test_img)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    # Grad cam time
    detr_cam = GradCAM(model=detr_model, target_layers=detr_target_layers, use_cuda=False, reshape_transform=None, classification_logit="pred_logits")
    detr_grayscale_cam = detr_cam(input_tensor=input_batch, target_category=target_category, eigen_smooth=False, aug_smooth=False)
    detr_grayscale_cam = detr_grayscale_cam[0, :]

    # process image to write gradcam on
    rgb_image = np.array(detr_transform_eval(test_img)).astype(np.float32)
    rgb_image = rgb_image/255

    # whole image gradcam visualization
    detr_heatmap, detr_visualization = show_cam_on_image_updated(rgb_image, detr_grayscale_cam, use_rgb=False)
    cv2.imwrite(detr_path, detr_visualization)

    # resize bbox and calculate metrics
    detr_input_image_shape = (detr_grayscale_cam.shape[0], detr_grayscale_cam.shape[1], 3)
    new_bbox_detr = resizeBbox(orig_bbox, (orig_img_shape[0], orig_img_shape[1]), (detr_input_image_shape[0], detr_input_image_shape[1]))
    detr_visualized_cam_threshold = visualize_eval_metric(rgb_image, detr_grayscale_cam, detr_heatmap, new_bbox_detr, threshold)
    cv2.imwrite(detr_path_t, detr_visualized_cam_threshold)
# Out:
# <class 'tuple'>
# The max logit value is [tensor(5.5308, grad_fn=<AddBackward0>)]
# /root/.cache/torch/hub/facebookresearch_detr_main/models/position_encoding.py:41: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
# <class 'dict'>
# The max logit value is [tensor(13.5611, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.9925, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1433, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.5802, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5805, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-10.4102, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3409, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.7897, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6876, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.7237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1653, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.8391, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5269, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.6263, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8881, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.5815, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5420, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.6381, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3702, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.4378, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0519, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5853, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.3439, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1189, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.2419, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7280, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.5862, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2912, grad_fn=<AddBackward0>), tensor(12.8169, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.2505, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7286, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.4982, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7591, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.8589, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2224, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.2969, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0014, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.8186, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.9192, grad_fn=<AddBackward0>), tensor(12.4240, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.2846, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1706, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.8542, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.3482, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.0436, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5283, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.4073, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.4699, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-13.0639, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8216, grad_fn=<AddBackward0>), tensor(13.7852, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.9264, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2152, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.7400, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8655, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.5422, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7718, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.4477, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2496, grad_fn=<AddBackward0>), tensor(10.3612, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-15.4661, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1834, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.5230, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2386, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.9237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8533, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.4350, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.4381, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.4023, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.5508, grad_fn=<AddBackward0>), tensor(10.1962, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.9054, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.0500, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.4827, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2102, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.1681, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3062, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-3.6744, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0674, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.1773, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7987, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-7.5615, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8895, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(5.9256, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1859, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9152, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.0157, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1642, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-4.8990, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3817, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-9.0738, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9484, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.7179, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6399, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(2.3924, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2561, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.9677, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.7378, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.7508, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1482, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(1.8393, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4236, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.0784, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2230, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.4209, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6074, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.4780, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9774, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-8.8036, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1900, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-7.8244, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2619, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-0.5951, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.0699, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.4417, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.3201, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.7145, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3823, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-5.5045, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5649, grad_fn=<AddBackward0>), tensor(10.6699, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-7.5828, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7559, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.7581, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.7177, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.3396, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8450, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-4.2198, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6159, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.9254, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5183, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-10.2075, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4458, grad_fn=<AddBackward0>), tensor(10.8906, grad_fn=<AddBackward0>), tensor(10.5400, grad_fn=<AddBackward0>), tensor(9.5037, grad_fn=<AddBackward0>), tensor(10.5132, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.3321, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3324, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.3800, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9643, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.5889, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1103, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.5506, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6464, grad_fn=<AddBackward0>), tensor(10.3465, grad_fn=<AddBackward0>), tensor(10.9078, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-13.3801, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.1126, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.9034, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9821, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.3267, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6656, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.8161, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9558, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.7174, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6899, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.4084, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3030, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.5086, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0514, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.8309, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8245, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(5.7582, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8324, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.5599, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.1073, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.7845, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3465, grad_fn=<AddBackward0>), tensor(12.2098, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.1103, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2999, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-10.1368, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6304, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-9.6012, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3417, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-9.6016, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5807, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-4.7332, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.4389, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.3527, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8786, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.7406, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6798, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.0412, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5863, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.8322, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.9161, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.0760, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2207, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.8192, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1463, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-13.7556, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2732, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.6488, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8657, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.8614, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6885, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.5220, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9689, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.5919, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6179, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.6957, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5961, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.7360, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9742, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(1.4690, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5712, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-8.8549, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(8.7585, grad_fn=<AddBackward0>)]

# %%
output_images_dir = proj_dir + '/Q1/output_images_blank_background/'
generate_vis_analysis = True

if(generate_vis_analysis):
  for i in range(0, len(image_names)):
    # Create input
    test_img = Image.open( dataset_folder + '/' + image_names[i] ).convert('RGB')
    yolo_path = output_images_dir + 'yolo/' + image_names[i].split('.')[0] + '_yolo_whole.' + image_names[i].split('.')[1]
    detr_path = output_images_dir + 'detr/' + image_names[i].split('.')[0] + '_detr_whole.' + image_names[i].split('.')[1]

    # Create target lable
    target_name = image_names[i].split( '-' )[1]
    target_name = target_name.split( '.' )[0]

    #
    # YOLO
    #
    
    # YOLO Target label
    # handle mismatch spelling in yolo classes
    yolo_target_name = target_name
    if yolo_target_name == 'airplane':
      yolo_target_name = 'aeroplane'
      
    target_category = [index for index, class_instance in enumerate(yolo_classes) if class_instance == yolo_target_name]

    # Input
    input_tensor = yolo_transform(test_img)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    # Grad cam time
    yolo_cam = GradCAM(model=yolo_model, target_layers=yolo_target_layers, use_cuda=False, reshape_transform=None, classification_logit="pred_logits")
    yolo_grayscale_cam = yolo_cam(input_tensor=input_batch, target_category=target_category, eigen_smooth=False, aug_smooth=False)
    yolo_grayscale_cam = yolo_grayscale_cam[0, :]

    # process image to write gradcam on
    rgb_image = np.array(yolo_transform_eval(test_img)).astype(np.float32)
    rgb_image = rgb_image/255

    # whole image gradcam visualization
    yolo_heatmap, yolo_visualization = show_cam_on_image_updated_blank(rgb_image, yolo_grayscale_cam, use_rgb=False)
    cv2.imwrite(yolo_path, yolo_visualization)


    ######


    #
    # DETR
    #

    # DETR Target Label
    target_category = [index for index, class_instance in enumerate(DETR_CLASSES) if class_instance == target_name]

    # Input
    input_tensor = detr_transform(test_img)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    # Grad cam time
    detr_cam = GradCAM(model=detr_model, target_layers=detr_target_layers, use_cuda=False, reshape_transform=None, classification_logit="pred_logits")
    detr_grayscale_cam = detr_cam(input_tensor=input_batch, target_category=target_category, eigen_smooth=False, aug_smooth=False)
    detr_grayscale_cam = detr_grayscale_cam[0, :]

    # process image to write gradcam on
    rgb_image = np.array(detr_transform_eval(test_img)).astype(np.float32)
    rgb_image = rgb_image/255

    # whole image gradcam visualization
    detr_heatmap, detr_visualization = show_cam_on_image_updated_blank(rgb_image, detr_grayscale_cam, use_rgb=False)
    cv2.imwrite(detr_path, detr_visualization)
# Out:
# <class 'tuple'>
# The max logit value is [tensor(5.5308, grad_fn=<AddBackward0>)]
# /root/.cache/torch/hub/facebookresearch_detr_main/models/position_encoding.py:41: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
# <class 'dict'>
# The max logit value is [tensor(13.5611, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.9925, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1433, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.5802, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5805, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-10.4102, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3409, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.7897, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6876, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.7237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1653, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.8391, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5269, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.6263, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8881, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.5815, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5420, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.6381, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3702, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.4378, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0519, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5853, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.3439, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1189, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.2419, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7280, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.5862, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2912, grad_fn=<AddBackward0>), tensor(12.8169, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.2505, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7286, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.4982, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7591, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.8589, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2224, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.2969, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0014, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.8186, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.9192, grad_fn=<AddBackward0>), tensor(12.4240, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.2846, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1706, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.8542, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.3482, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.0436, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5283, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.4073, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.4699, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-13.0639, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8216, grad_fn=<AddBackward0>), tensor(13.7852, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.9264, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2152, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.7400, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8655, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.5422, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7718, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.4477, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2496, grad_fn=<AddBackward0>), tensor(10.3612, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-15.4661, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1834, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.5230, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.2386, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.9237, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8533, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.4350, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.4381, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.4023, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.5508, grad_fn=<AddBackward0>), tensor(10.1962, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.9054, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.0500, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.4827, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2102, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.1681, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3062, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-3.6744, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0674, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.1773, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7987, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-7.5615, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8895, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(5.9256, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1859, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.8042, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9152, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.0157, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.1642, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-4.8990, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3817, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-9.0738, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9484, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.7179, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6399, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(2.3924, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2561, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.9677, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.7378, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.7508, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1482, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(1.8393, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4236, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.0784, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2230, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(8.4209, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6074, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.4780, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9774, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-8.8036, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(15.1900, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-7.8244, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2619, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-0.5951, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.0699, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.4417, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.3201, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.7145, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.3823, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-5.5045, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5649, grad_fn=<AddBackward0>), tensor(10.6699, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-7.5828, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.7559, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(4.7581, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.7177, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.3396, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8450, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-4.2198, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6159, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(10.9254, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5183, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-10.2075, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.4458, grad_fn=<AddBackward0>), tensor(10.8906, grad_fn=<AddBackward0>), tensor(10.5400, grad_fn=<AddBackward0>), tensor(9.5037, grad_fn=<AddBackward0>), tensor(10.5132, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.3321, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3324, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.3800, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9643, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.5889, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.1103, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.5506, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6464, grad_fn=<AddBackward0>), tensor(10.3465, grad_fn=<AddBackward0>), tensor(10.9078, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-13.3801, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(9.1126, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.9034, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9821, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.3267, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6656, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.8161, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9558, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.7174, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.6899, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.4084, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3030, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.5086, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.0514, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.8309, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8245, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(5.7582, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.8324, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.5599, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.1073, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.7845, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.3465, grad_fn=<AddBackward0>), tensor(12.2098, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.1103, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.2999, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-10.1368, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6304, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-9.6012, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.3417, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-9.6016, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.5807, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-4.7332, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.4389, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(9.3527, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.8786, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-14.7406, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6798, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.0412, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5863, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.8322, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.9161, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-11.0760, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(14.2207, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.8192, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.1463, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-13.7556, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.2732, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(7.6488, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(10.8657, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-12.8614, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.6885, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.5220, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.9689, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(6.5919, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(13.6179, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.6957, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.5961, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(3.7360, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(12.9742, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(1.4690, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(11.5712, grad_fn=<AddBackward0>)]
# <class 'tuple'>
# The max logit value is [tensor(-8.8549, grad_fn=<AddBackward0>)]
# <class 'dict'>
# The max logit value is [tensor(8.7585, grad_fn=<AddBackward0>)]
